# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics

# %% [markdown]
# First, I imported the datasetes given to us about the real estate in King County, Washington.

# %% [markdown]
# # Column Names and descriptions for Kings County Data Set
# * **id** - unique identified for a house
# * **dateDate** - house was sold
# * **pricePrice** -  is prediction target
# * **bedroomsNumber** -  of Bedrooms/House
# * **bathroomsNumber** -  of bathrooms/bedrooms
# * **sqft_livingsquare** -  footage of the home
# * **sqft_lotsquare** -  footage of the lot
# * **floorsTotal** -  floors (levels) in house
# * **waterfront** - House which has a view to a waterfront
# * **view** - Has been viewed
# * **condition** - How good the condition is ( Overall )
# * **grade** - overall grade given to the housing unit, based on King County grading system
# * **sqft_above** - square footage of house apart from basement
# * **sqft_basement** - square footage of the basement
# * **yr_built** - Built Year
# * **yr_renovated** - Year when house was renovated
# * **zipcode** - zip
# * **lat** - Latitude coordinate
# * **long** - Longitude coordinate
# * **sqft_living15** - The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15** - The square footage of the land lots of the nearest 15 neighbors

# %%
df = pd.read_csv('data/kc_house_data.csv')

# %%
df.head(10)
# Out:
#            id        date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014   221900.0         3       1.00         1180
# 1  6414100192   12/9/2014   538000.0         3       2.25         2570
# 2  5631500400   2/25/2015   180000.0         2       1.00          770
# 3  2487200875   12/9/2014   604000.0         4       3.00         1960
# 4  1954400510   2/18/2015   510000.0         3       2.00         1680
# 5  7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6  1321400060   6/27/2014   257500.0         3       2.25         1715
# 7  2008000270   1/15/2015   291850.0         3       1.50         1060
# 8  2414600126   4/15/2015   229500.0         3       1.00         1780
# 9  3793500160   3/12/2015   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# ...

# %% [markdown]
# I then cleaned the data by removing the columns I did not need. I also used .describe to find things such as the mean, standard deviation, and IQRs of the remaining columns.

# %%
df = df.rename(columns = {"date":"date_sold"})

# %% [markdown]
# Columns looking at:
# price
# bedrooms
# bathrooms
# sqft_living
# sqft_lot
# floors
# zipcode

# %%
df_1 = df.drop(['id', 'waterfront', 'view', 'grade', 'sqft_above', 'sqft_basement', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'condition'], axis = 1)

# %%
df_1.head()
# Out:
#     date_sold     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    yr_built  yr_renovated  zipcode
# 0      1955           0.0    98178
# 1      1951        1991.0    98125
# 2      1933           NaN    98028
# 3      1965           0.0    98136
# 4      1987           0.0    98074

# %%
df_1.dropna()
# Out:
#         date_sold      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      10/13/2014   221900.0         3       1.00         1180      5650
# 1       12/9/2014   538000.0         3       2.25         2570      7242
# 3       12/9/2014   604000.0         4       3.00         1960      5000
# 4       2/18/2015   510000.0         3       2.00         1680      8080
# 5       5/12/2014  1230000.0         4       4.50         5420    101930
# ...           ...        ...       ...        ...          ...       ...
# 21592   5/21/2014   360000.0         3       2.50         1530      1131
# 21593   2/23/2015   400000.0         4       2.50         2310      5813
# 21594   6/23/2014   402101.0         2       0.75         1020      1350
# 21595   1/16/2015   400000.0         3       2.50         1600      2388
# 21596  10/15/2014   325000.0         2       0.75         1020      1076
#
#        floors  yr_built  yr_renovated  zipcode
# ...

# %%
df_2 = df_1
df_2.head()
# Out:
#     date_sold     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    yr_built  yr_renovated  zipcode
# 0      1955           0.0    98178
# 1      1951        1991.0    98125
# 2      1933           NaN    98028
# 3      1965           0.0    98136
# 4      1987           0.0    98074

# %%
df_2.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# mean   5.402966e+05      3.373200      2.115826   2080.321850  1.509941e+04
# std    3.673681e+05      0.926299      0.768984    918.106125  4.141264e+04
# min    7.800000e+04      1.000000      0.500000    370.000000  5.200000e+02
# 25%    3.220000e+05      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068500e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors      yr_built  yr_renovated       zipcode
# count  21597.000000  21597.000000  17755.000000  21597.000000
# mean       1.494096   1970.999676     83.636778  98077.951845
# std        0.539683     29.375234    399.946414     53.513072
# ...

# %%
df_2.price.mean()
# Out:
# 540296.5735055795

# %%
df_2.price.std()
# Out:
# 367368.1401013945

# %%
df_2.std(axis = 0, skipna = True)
# Out:
# price           367368.140101
# bedrooms             0.926299
# bathrooms            0.768984
# sqft_living        918.106125
# sqft_lot         41412.636876
# floors               0.539683
# yr_built            29.375234
# yr_renovated       399.946414
# zipcode             53.513072
# dtype: float64

# %%
upper_limit = df_2.price.mean() + 2*df_2.price.std()
upper_limit
# Out:
# 1275032.8537083685

# %%
upper_limit = round(1275032.8537083685, 2)
upper_limit
# Out:
# 1275032.85

# %%
lower_limit = df_2.price.mean() - 1*df_2.price.std()

# %%
lower_limit = round(172928.433404185, 2)
lower_limit
# Out:
# 172928.43

# %%
values = df_2[ (df_2['price'] >= 172928.43) & (df_2['price'] <= 1275032.85)].index

# %%
df_2.drop(values, inplace = False)
# Out:
#         date_sold      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 21      8/26/2014  2000000.0         3       2.75         3050     44867
# 49      3/11/2015  1350000.0         3       2.50         2753     65005
# 69      6/12/2014  1330000.0         5       2.25         3200     20158
# 92      2/26/2015   153000.0         3       1.00         1200     10500
# 118      1/8/2015   171800.0         4       2.00         1570      9600
# ...           ...        ...       ...        ...          ...       ...
# 21535  12/24/2014  1380000.0         5       4.50         4350     13405
# 21552   1/30/2015  1700000.0         4       3.50         3830      8963
# 21560    1/7/2015  3570000.0         5       4.50         4850     10584
# 21581   4/21/2015  1580000.0         4       3.25         3410     10125
# 21584  10/15/2014  1540000.0         5       3.75         4470      8088
#
#        floors  yr_built  yr_renovated  zipcode
# ...

# %%
df_1.head()
# Out:
#     date_sold     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    yr_built  yr_renovated  zipcode
# 0      1955           0.0    98178
# 1      1951        1991.0    98125
# 2      1933           NaN    98028
# 3      1965           0.0    98136
# 4      1987           0.0    98074

# %%
df_1.shape
# Out:
# (21597, 10)

# %%
df_1 = df_1.rename(columns = {'price':'amount'})

# %%
outliers = df_1[ (df_1['bedrooms'] >= 4) & (df_2['bathrooms'] >= 3)].index

# %%
df_1.drop(outliers, inplace = False)
# Out:
#         date_sold    amount  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      10/13/2014  221900.0         3       1.00         1180      5650
# 1       12/9/2014  538000.0         3       2.25         2570      7242
# 2       2/25/2015  180000.0         2       1.00          770     10000
# 4       2/18/2015  510000.0         3       2.00         1680      8080
# 6       6/27/2014  257500.0         3       2.25         1715      6819
# ...           ...       ...       ...        ...          ...       ...
# 21592   5/21/2014  360000.0         3       2.50         1530      1131
# 21593   2/23/2015  400000.0         4       2.50         2310      5813
# 21594   6/23/2014  402101.0         2       0.75         1020      1350
# 21595   1/16/2015  400000.0         3       2.50         1600      2388
# 21596  10/15/2014  325000.0         2       0.75         1020      1076
#
#        floors  yr_built  yr_renovated  zipcode
# 0         1.0      1955           0.0    98178
# ...

# %%
#amount=df_1('amount')
Price_by_bed_and_bath = df_1.value_counts()[:10]
x = amount.index
y = bed_bath.values

plot_one_fig, plot_one_ax = plt.subplots(figsize=(15,6))

plot_one_ax.bar(x,y)
plot_one_ax.set_xlabel('Price', fontsize=15)
plot_one_ax.set_ylabel('Bed and Bath Total', fontsize=15)
plot_one_ax.set_title('Pice of House based on the Total Bed and Bath', fontsize=35)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-7d1a98a9dfa0> in <module>
#       1 #amount=df_1('amount')
#       2 Price_by_bed_and_bath = df_1.value_counts()[:10]
# ----> 3 x = amount.index
#       4 y = bed_bath.values
#       5
#
# NameError: name 'amount' is not defined

# %%
sns.relplot(x='amount', y='bed_bath', df_1=df_1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-b434a2c3aa7f> in <module>
# ----> 1 sns.relplot(x='amount', y='bed_bath', df_1=df_1)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     931
#     932     # Use the full dataset to map the semantics
# --> 933     p = plotter(
#     934         data=data,
# ...
